# %%
import re
import pandas as pd

# %%
import ast
import json

# %%
alphabets= "([A-Za-z])"
prefixes = "(Mr|St|Mrs|Ms|Dr)[.]"
suffixes = "(Inc|Ltd|Jr|Sr|Co)"
starters = "(Mr|Mrs|Ms|Dr|He\s|She\s|It\s|They\s|Their\s|Our\s|We\s|But\s|However\s|That\s|This\s|Wherever)"
acronyms = "([A-Z][.][A-Z][.](?:[A-Z][.])?)"
websites = "[.](com|net|org|io|gov)"

def split_into_sentences(text):
    text = " " + text + "  "
    text = text.replace("\n"," ")
    text = re.sub(prefixes,"\\1<prd>",text)
    text = re.sub(websites,"<prd>\\1",text)
    if "Ph.D" in text: text = text.replace("Ph.D.","Ph<prd>D<prd>")
    text = re.sub("\s" + alphabets + "[.] "," \\1<prd> ",text)
    text = re.sub(acronyms+" "+starters,"\\1<stop> \\2",text)
    text = re.sub(alphabets + "[.]" + alphabets + "[.]" + alphabets + "[.]","\\1<prd>\\2<prd>\\3<prd>",text)
    text = re.sub(alphabets + "[.]" + alphabets + "[.]","\\1<prd>\\2<prd>",text)
    text = re.sub(" "+suffixes+"[.] "+starters," \\1<stop> \\2",text)
    text = re.sub(" "+suffixes+"[.]"," \\1<prd>",text)
    text = re.sub(" " + alphabets + "[.]"," \\1<prd>",text)
    if "”" in text: text = text.replace(".”","”.")
    if "\"" in text: text = text.replace(".\"","\".")
    if "!" in text: text = text.replace("!\"","\"!")
    if "?" in text: text = text.replace("?\"","\"?")
    text = text.replace(".",".<stop>")
    text = text.replace("?","?<stop>")
    text = text.replace("!","!<stop>")
    text = text.replace("<prd>",".")
    sentences = text.split("<stop>")
    sentences = sentences[:-1]
    sentences = [s.strip() for s in sentences]
    return sentences

# %%
#text=['Dr Nelson and her staff are wonderful! They are always on time and very caring!', 'Dr. Nelson was our family pediatrician for over 20 years when I was a child. I am a first time mom and my children will not go to any other pediatrician. Dr. Nelson is thoughtful, knowledge, and wonderful with both the children and parents. She is the best pediatrician.', 'Dr Nelson is amazing. One thing that I\'ve noticed sets her apart is she truly knows and cares for all of her patients. You are not just another name scheduled for the day. Martine is an extremely confident, easy going, intelligent, and compassionate provider. In my opinion you are hard pressed to find that combo many places.', 'Been going here for 21 years. BEST DOCTOR AROUND!! I love Doctor Nelson :)', 'I have a five year old and a three year old and they have been going to Dr. Nelson since they were born. We all love Dr. Nelson. She is knowledgeable, kind and thorough. We have had several issues over the years and Dr. Nelson and her staff have always been very helpful!', 'Dr Nelson is a blessing! She is always very prompt, attentive and most importantly, available whenever you need her! Her staff is exceptional too.', 'I saw Dr. Nelson for 22 years and she is amazing! Always very helpful and attentive, a wonderful Dr.', 'Dr. Nelson is the ultimate best doctor. Our family has been with her for about 21 years and we trust her unconditionally. She always takes the time to explain everything. When our kids were ill, we were always able to get in to see her within a couple of hours - amazing! We feel very fortunate to have found her for our pediatrician. Thank you Dr. Nelson!!', "I have a three year old and a new born. Dr. Nelson has been great with both of them. When my daughter was having some problems, Dr. Nelson called us daily to check in on her. I was a very tense first time mom and Dr. Nelson's office always answered all my questions and they never made me feel bad for calling them all the time!", "I felt that this doctor was much too busy. Each time I saw her she didn't seem to remember the details of my situation. I usually had to wait at least an hour every appointment. Once I even waited 3 hours! In addition she didn't explain things very thoroughly. She does seem to be a friendly person but overall I felt insignificant to this doctor and will not be going to her for any future pregnancies.", "I've been taking my kids to Dr. Nelson since my 5 year old was born. She's great! And her staff is wonderful too!", 'Dr. Nelson has been my "19" year olds doctor since birth! We were her first patient and would follow her anywhere! She is a blessing!!!', 'Doctor Nelson is wonderful! She has a ready ear, returns calls personally, answers questions, quells fears and educated her patients.', 'Very knowledgeable, thorough, easy to talk to, and compassionate. I went through a scary problem, and she was very supportive and thorough in testing, explaining treatment and options. Highly recommended.']
#sen=split_into_sentences(str(text))

# %%
#t2=str(text)
#sent=re.split(r'[\.\?!][\'"\)\]]*',t2)
#print(type(sent))

# %%
#hgrd=pd.read_excel(r'C:\Users\rramn\Documents\Healthcare_analytics\physician_reviews_mining\Reviews\healthgrades_reviews.xlsx')
ratemd=pd.read_csv(r'/Users/sujaikarunakaran/Desktop/Assignments/Spring 2020/Ranga/Final Project/Final/Healthgrades/All_Healthgrades_v3.csv')
#ratemd = pd.read_csv(r'/Users/sujaikarunakaran/Desktop/Assignments/Spring 2020/Ranga/Final Project/Final/RateMds/complete_data_ratemds.csv')
ratemd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 840 entries, 0 to 839
# Data columns (total 8 columns):
# DoctorName             840 non-null object
# Age                    839 non-null float64
# Affiliated Hospital    839 non-null object
# Gender                 840 non-null object
# Education              834 non-null object
# Experience             840 non-null int64
# Rating                 840 non-null float64
# Reviews                840 non-null object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 52.6+ KB

# %%
from nltk import tokenize

# %%
type(ratemd["Doctor_reviews"])
# Out:
# pandas.core.series.Series

# %%
type(ratemd["Reviews"])
# Out:
# pandas.core.series.Series

# %%
su = ratemd["Reviews"][38]

# %%
#su = su.split("', '|\", \"|', \"|\", '|\",\"")
su = su.strip("][").split(",")

# %%
len(su[0])
# Out:
# 454

# %%
su[1]
# Out:
# " 'I have been with Dr. Das for 15 years. She is a excellent Doctor. Dr. Das has such great compassion and grace. When I was told years ago I was 2nd. stage pre- cervical cancer"

# %%
jai = ast.literal_eval(su)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-304-5f9b92d563fc> in <module>
# ----> 1 jai = ast.literal_eval(su)
#
# ~/anaconda3/lib/python3.7/ast.py in literal_eval(node_or_string)
#      89                     return left - right
#      90         return _convert_signed_num(node)
# ---> 91     return _convert(node_or_string)
#      92
#      93
#
# ~/anaconda3/lib/python3.7/ast.py in _convert(node)
#      88                 else:
#      89                     return left - right
# ---> 90         return _convert_signed_num(node)
#      91     return _convert(node_or_string)
#      92
#
# ~/anaconda3/lib/python3.7/ast.py in _convert_signed_num(node)
#      61             else:
#      62                 return - operand
# ---> 63         return _convert_num(node)
#      64     def _convert(node):
#      65         if isinstance(node, Constant):
#
# ~/anaconda3/lib/python3.7/ast.py in _convert_num(node)
#      53         elif isinstance(node, Num):
#      54             return node.n
# %%
len(jai)
# Out:
# 3

# %%
jai
# Out:
# ['She is The BEST!!!',
#  'Dr. Chaudhari is an amazing Physician! Her indept concern and compassion, for me and her overall patients, is phenomenal! I love her so and I entrust my healthcare and issues to her! Bless you Dr. Chaudhari! You and your staff are awesome!!!!!She is one of the BEST at NW Hospital. You Rock Dr. C!!!!!',
#  "Dr. Chaudhari is amazing. An experther field but also so friendly, warm, and relatable. She takes time to listen and explain thingsreal speak, not medical jargon. Something you just don't often finda specialist. My daughter saw her for a cyst that her OB recommended be removed, but after further review by Dr. Chaudhari, she found that she won't need surgery at this point and she will just monitor it annually. So happy we found her. Absolutely love her."]

# %%
ratemd["Single_review"] = ratemd["Doctor_reviews"].to_list()

# %%
type(ratemd["Single_review"][38])
# Out:
# str

# %%
#senthg=[]
sentrm=[]
doc_names = []
star_rating = []
gender = []
hos_affil = []
#nr,nc=hgrd.shape
nr1,nc1=ratemd.shape
#hgrd.info()
#for i in range(nr):
#    t=hgrd.iloc[i,6]
#    sent=re.split(r'[\.\?!][\'"\)\]]*',t)
#    senthg.append(sent)

for j in range(nr1):
    name = ratemd.iloc[j,0]
    #rating = ratemd.iloc[j,3]
    #gend = ratemd.iloc[j,1]
    #ha = ratemd.iloc[j,4]
    t1=ratemd.iloc[j,7]
    #sent1 = tokenize.sent_tokenize(t1)
    #sent1 = split_into_sentences(t1)
    #sent1=re.split(r'[\.\?!][\'"\)\]]*|,|and|but',t1)
    #sent1=re.split(r"'|.|!|,|\"|?|and|but",t1)
    #sent1=re.split(r".|,|'|\"|and|but", t1)
    for x in t1:
        x_sent = x
        sentrm.append(x_sent)
        doc_names.append(name)
        #star_rating.append(rating)
        #gender.append(gend)
        #hos_affil.append(ha)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-204-ab51e6e92b57> in <module>
#      24     #sent1=re.split(r"'|.|!|,|\"|?|and|but",t1)
#      25     #sent1=re.split(r".|,|'|\"|and|but", t1)
# ---> 26     for x in t1:
#      27         x_sent = x
#      28         sentrm.append(x_sent)
#
# TypeError: 'numpy.float64' object is not iterable

# %%
#senthg=[]
sentrm=[]
doc_names = []
star_rating = []
gender = []
hos_affil = []
#nr,nc=hgrd.shape
nr1,nc1=ratemd.shape
#hgrd.info()
#for i in range(nr):
#    t=hgrd.iloc[i,6]
#    sent=re.split(r'[\.\?!][\'"\)\]]*',t)
#    senthg.append(sent)

for j in range(nr1):
    name = ratemd.iloc[j,0]
    #rating = ratemd.iloc[j,3]
    #gend = ratemd.iloc[j,1]
    #ha = ratemd.iloc[j,4]
    t1=ratemd.iloc[j,7]
    t1 = t1.strip("][").split(",")
    #sent1 = tokenize.sent_tokenize(t1)
    #sent1 = split_into_sentences(t1)
    #sent1=re.split(r'[\.\?!][\'"\)\]]*|,|and|but',t1)
    #sent1=re.split(r"'|.|!|,|\"|?|and|but",t1)
    #sent1=re.split(r'\',"', t1)
    #for x in sent1:
    for x in range(len(t1)):
        x_sent = t1[x]
        sentrm.append(x_sent)
        doc_names.append(name)
    #star_rating.append(rating)
    #gender.append(gend)
    #hos_affil.append(ha)

# %%
len(sentrm)
# Out:
# 10424

# %%
de = {"Doc_names":doc_names, "Review_phrases":sentrm}

# %%
df = pd.DataFrame(de)

# %%
df.shape
# Out:
# (10424, 2)

# %%
sentrm
# Out:
# ["['I have been a patient for over 33 years",
#  ' He is simply the best',
#  '',
#  " 'Dr",
#  ' Drachler is very knowledgeable',
#  ' His bedside manners are simply perfect',
#  ' I am not the easiest patient out there',
#  '',
#  '',
#  '',
#  ' I can truly say that Dr',
#  ' Drachler is an excellent example of how a physician who took the Oath of Hyppocrates should be',
#  ' Five stars on knowledge',
#  ' bedside manners',
#  ' punctuality ',
#  ' helpfulness',
#  ' Simple as that',
#  '',
#  " 'It was my first ",
#  ' last visit',
#  ' He came over as unfriendly ',
#  ' condescending',
#  ' He was rude ',
#  ' had the worst bedside manner',
#  ' I felt very bad about this visit',
#  '',
#  " 'God has truly answered my prayers ",
#  ' sustained my life through 30+ years of medical challenges',
#  ' Dr',
#  ' A',
#  ' Michael Drachler is God-sent directly from Heaven',
#  ' Through all my too-numerous-to-count pre-op',
#  ' surgeries ',
#  ' office visits',
#  ' he has been my lifeline',
#  ' He is so extremely caring',
#  ' competent ',
#  ' skillful in OB/GYN',
#  ' I trust him completely ',
#  ' every time I encountered a medical issue outside his scope of expertise',
#  ' I asked Dr',
#  ' Drachler to refer me to my other physicians',
#  ' I admire Dr',
#  ' Drachler greatly',
#  ' He not only loves to bring new life into the world ',
#  ' Dr',
#  ' Drachler is seriously concerned about the quality of our lives',
#  '',
#  '',
#  ' as women',
#  '',
#  '',
#  'to be healthy ',
#  ' living life to the fullness',
#  ' He addresses ',
#  ' cures my issues',
#  '',
#  '',
#  ' not masks them with pain meds ',
#  ' send me away (like the previous OB/GYN which I left did to me)',
#  ' Dr',
#  ' Drachler is truly one of a kind',
#  ' A couple I referred were not conceiving so I told her to go see my doctor',
#  ' 1 visit with Dr',
#  ' Drachler',
#  ' she was pregnant within 30 days',
#  '',
#  " 'Dr",
#  ' Drachler is very caring',
#  'knowledgeable ',
#  ' patient',
#  ' He truly spends the time to clarify ',
#  ' explain procedures ',
#  ' details ',
#  ' will not end the visit until you are ready',
#  '',
#  " 'Dr",
#  ' Drachler is one of the best doctors I have ever met',
#  ' He is extremely knowledgeable ',
#  ' explained everything to me ',
#  ' my husb',
#  ' like nobody ever did',
#  ' I would definitely recommend seeding him',
#  ' As you know most doctors see you for 5-10 minutes ',
#  ' run away to next patient',
#  ' ',
#  ' Dr',
#  ' Drachler spent with us 1 whole hour',
#  '',
#  '',
#  ' I was very impressed with no rushing',
#  ' no pushing',
#  ' ',
#  ' especially his positive attitude',
#  '',
#  " 'I have been with Dr",
#  ' Drachler for about 30 years',
#  ' He is the absolute best',
#  ' Caring',
#  ' underst',
#  'ing ',
#  ' more',
#  ' I recently asked him if he was planning to retire',
#  ' It is so awful when your doctors retire ',
#  ' then you have to hunt for someone to replace "the best"',
#  " He told me \\'until there is no more to learn he would be there for me\\'",
#  ' You could not choose a more wonderful',
#  ' caring doctor',
#  '',
#  "['Terrible experience",
#  ' I have been a patient of hers for many years ',
#  ' finally decided to change doctors',
#  ' She makes you wait forever before she comes in',
#  ' ',
#  ' she is not very personal',
#  '',
#  " 'She is rude ",
#  ' does not care about her patients',
#  '',
#  " 'She was my doctor through my first pregnancy ",
#  ' some unexpected',
#  ' very scary complications including a 6 week premature baby',
#  ' placental abruption',
#  ' ',
#  ' a baby with IUGR (growth restricted)',
#  ' None of these were genetic or predictable ',
#  ' were very scary',
#  ' She was kind ',
#  ' confident throughout the entire process',
#  ' She delivered my 3lb baby calmly ',
#  ' sensitively--keeping me informed throughout the entire process',
#  ' I would refer her to my family ',
#  ' friends',
#  ' I am pregnant with my second child',
#  ' ',
#  ' we have chosen her to be our doctor again',
#  '',
#  " 'The woman looked bored the second she came into my room",
#  ' She took my story ',
#  ' treated me like I was a crazy person',
#  ' I then went to a scheduled test she ordered for me',
#  ' When I went 3 days later to follow up on the results',
#  ' I sat in her office for 40 minutes while they tried to "find my results"',
#  ' This woman never even came out to see me',
#  ' Called me the next day with some lame excuse',
#  ' Was very doubtful of my pain ',
#  ' basically told me my pain was way worse then it should be',
#  ' I am a nurse ',
#  ' know pain',
#  ' She is rude ',
#  ' does have a terrible attitude',
#  ' She should be kinder to people who are in severe pain ',
#  ' not look at them like they have 3 heads',
#  ' Will never go back',
#  ' And I will tell people of my experience',
#  ' I am sure she will not care',
#  ' ',
#  ' maybe she will re-think the way she treats others',
#  '',
#  " 'This doctor is rude ",
#  '',
#  '',
#  'maybe she is great at what she does ',
#  " has a bad attitude'",
#  ' "Had only one visit with her for my preventative care yearly gyn checkup',
#  ' She seemed fake ',
#  ' I felt very rushed when I was asking her questions',
#  ' I told her up front that I had questions',
#  ' ',
#  ' she went into this whole schpiel saying let me do the talking while I do your checks ',
#  " at the end if I haven't answered your questions you may ask them then",
#  " She didn't seem like she cared ",
#  ' just wanted to move on to the next patient',
#  ' Switched doctors immediately',
#  '',
#  " 'Had to call for my results",
#  '',
#  '',
#  '',
#  'after receiving the bill with the diagnosis',
#  " terrible']",
#  '["Dr',
#  ' Roth is great',
#  ' She totally knows her stuff ',
#  ' instills confidence in her patients',
#  ' She has an excellent bedside manner ',
#  ' knows just how to h',
#  'le pregnant/hormonal women',
#  ' She does often seem rushed',
#  ' ',
#  ' if you pipe up she will answer all your questions',
#  " I wouldn't go to anyone else ",
#  ' I highly recommend her to others',
#  '',
#  ' \'I felt like it was a "drive through" appointment',
#  " I don\\'t feel I was looked at in depth",
#  ' ',
#  " merely a cursory examination'",
#  ' "I love Dr',
#  ' Roth',
#  ' All of my girlfriends see Dr',
#  ' Roth - ',
#  " we're her biggest fans",
#  '',
#  " 'Dr",
#  ' Abbie Roth is a great doctor',
#  ' She not only provides you with great medical information',
#  ' ',
#  ' she also provides you with a caring element',
#  ' I was referred to her by a friend',
#  ' ',
#  ' I too feel comfortable referring her to anyone I know',
#  " -----Chicago mom-to-be'",
#  ' "Great for older moms',
#  ' Previous poster must be mistaken',
#  ' Dr',
#  ' Roth has a super bedside manner',
#  ' She is very experienced with high-risk pregnancies ',
#  ' is an excellent surgeon for c-sections',
#  " You'll love her",
#  '',
#  ' "Not great for older mom\'s to be (over 35)',
#  '',
#  " 'She is great']",
#  "['I recently had a hysterectomy due to very large fibroids",
#  ' Dr shashoua was the best',
#  ' He calmed my fears',
#  ' explained everything clearly in a way I could underst',
#  ' ',
#  ' allowed me time to get all my questions answered',
#  ' His team was outst',
#  'ing ',
#  ' very attentive to my needs',
#  ' I feel very blessed to have been lucky enough to have him being the doctor to perform my surgery',
#  ' I would definitely recommend him to anyone facing surgery',
#  ' Thank-you so much Dr',
#  ' Shashua',
#  '',
#  " 'So I had fibroids for the past 12 years",
#  'My former Gynecologist told me one day I would need a hysterectomy',
#  ' After one failed UFE I was was done with this Dr',
#  ' of 28 years',
#  ' This past January',
#  ' I made an appointment with Dr',
#  ' Shashoua',
#  ' I had been researching him for about 7 years',
#  ' He examined me ',
#  ' right away did an ultrasound ',
#  ' said you need to have a hysterectomy',
#  ' So I trusted him ',
#  ' a few weeks later I went into Illinois Masonic hospital ',
#  ' had my hysterectomy',
#  ' I was extremely nervous',
#  ' I had never had major surgery',
#  ' I was not afraid of the pain',
#  ' But the anesthesia',
#  ' The nurses at IL Masonic were great',
#  ' \\nWell I have to say I am 7 1/2 weeks post-op ',
#  ' feel better than ever',
#  ' I have a hairline scare',
#  ' I can hardly see it',
#  ' Dr',
#  ' Shashoua changed my life',
#  ' I feel so much better without those fibroids',
#  ' I would highly recommend him if you have fibroids',
#  ' Thank you',
#  '',
#  " 'So grateful for the outst",
#  "ing results from surgery'",
#  " 'Dr",
#  'Shashua is the gold st',
#  'ard',
#  ' You do not get better than this',
#  '',
#  " 'Very caring ",
#  ' skilled doctor',
#  ' After childbirth I dealt with urinary incontinence for many years',
#  ' A 30 minute surgery has changed my life forever',
#  ' Thanks Dr',
#  " S'",
#  " ''",
#  ' "I went to Dr',
#  ' Shashoua for the first time 11/21/13 after hearing so many wonderful comments about him',
#  " I wasn't disappointed at all",
#  ' So far',
#  ' he seems to be a very patient ',
#  ' knowledgeable doctor',
#  ' I am 36yrs old ',
#  ' dealing with A LOT of fibroids',
#  ' He left the options on the table ',
#  ' was willing to work with whatever decisions',
#  ' I made',
#  ' Although',
#  ' his suggestion was not what I wanted to hear',
#  ' it was what he believes would be best',
#  ' He suggested a partial hyster ',
#  ' I want a myomectomy',
#  ' So',
#  ' he started me on Lupron for 2 mos to shrink the fibroids in preparation for a myomectomy',
#  ' Based on the number of fibroids',
#  ' I have',
#  ' He stated that they are MORE likely to grow back before I hit menopause',
#  ' I believe that God uses doctors',
#  ' ',
#  ' they are practicing',
#  ' God is the doctor',
#  ' So',
#  ' Im going to pray',
#  ' take this Lupron ',
#  ' go on a raw food diet fast (to help the medicine - lol) ',
#  ' WATCH GOD WORK THIS OUT',
#  '',
#  ' "Dr',
#  ' Shashoua is wonderful',
#  ' He is the best OB I have ever encountered ',
#  ' I was devistated when I found out he stopped delivering babies',
#  " He's just that good that any woman would want to be in his care for gyne issues",
#  ' He is gental ',
#  ' caring',
#  ' His office has ultrasound ',
#  ' the best exuiptment',
#  ' He ',
#  ' his staff are very supportative ',
#  ' underst',
#  'ing',
#  ' He works with you ',
#  ' he has the absolute best staff in the world - they are all so friendly',
#  ' He made it easy to see him ',
#  ' the appointment times were very flexible',
#  ' There is easy parking at Illinois Masonic',
#  ' He always returns calls personally ',
#  ' usually the same day',
#  ' The practice is small ',
#  ' very personal - they know your name ',
#  ' you feel like you belong',
#  ' They do ultrasounds right in the office instead of sending you to the hospital ',
#  ' their technology is fabulous',
#  ' He can send a script to your pharmacy electronicly - easy as 123',
#  '',
#  " 'Dr",
#  ' Shashoua is amazing',
#  ' He is compassionate',
#  ' ',
#  ' incredibly smart',
#  ' I have been his patient for 6 years ',
#  ' I have never doubted his ability',
#  ' skill',
#  ' kindness or genuine interest in my current ',
#  ' future health',
#  ' He had referred me to excellent doctors when needed ',
#  ' I plan on being his patient as long as he is available',
#  '',
#  ' "I have yet to encounter a more knowledgeable physician in all 8 years I\'ve been a patient of Dr',
#  " Shashoua's",
#  ' I have driven as far as 40 miles to the loop from the burbs to be seen by him',
#  ' Both of my children were delivered by Abraham ',
#  ' his great staff',
#  ' KJ"',
#  " 'The best doctor I have ever encountered",
#  ' Caring',
#  ' personable ',
#  ' highly skilled',
#  ' Takes care of my mother',
#  ' my daughter ',
#  ' myself with equal skill',
#  '',
#  '["I love her so much she was my doctor for my two boys ',
#  ' was gonna be for my last baby ',
#  ' she left I miss her so much she was so down to earth so was very caring ',
#  ' very concerned about her patients ',
#  " you can't find too many doctors that take their career to heart anymore its mainly the money ",
#  ' for her it was from her heart I miss you Dr kagumba"',
#  " 'Dr Kagumba has been my Ob/GYN for 9 years",
#  ' She has helped me navigate ongoing abnormal pap issues ',
#  ' performed a necessary hysterectomy with no complications',
#  ' She is very factual ',
#  ' easy to talk to about the straight forward action plan for dealing with your health issues',
#  ' That is what my husb',
#  ' ',
#  ' I have always appreciated about Dr Kagumba',
#  '',
#  " 'Used her for our first child",
#  ' Very smart doctor',
#  ' She really knows what she is doing',
#  ' She is very matter of fact ',
#  ' all business which may or may not be your thing',
#  '',
#  " 'Great",
#  ' caring doctor',
#  ' Great educational background',
#  ' Would recommend her to friends',
#  ' Woman of color',
#  ' if that is important to you',
#  '',
#  "['He might be a great doctor ",
#  ' his communication back to us after a diagnostic procedure has been inconsiderate to the point of negligence',
#  ' We were waiting for test results for possible cancer ',
#  ' my wife called his office at least 3 times',
#  " We haven\\'t received an update or a call back when promised",
#  " We\\'ve been promised yet another call ",
#  ' this time were given the worrying tidbit of information that "he needs to speak to another doctor first" - this is the most uncaring ',
#  " stressful approach to patient communications I\\'ve ever had the displeasure of being exposed to in my life (I\\'m 48)",
#  " I hope somebody in the doctor\\'s office reads this ",
#  ' gets a clue',
#  " I\\'d have chewed him out already ",
#  ' wife is a kinder soul than I am ',
#  ' has kept me from calling',
#  '',
#  ' "I\'ve been seeing Dr Cohan for 8 yrs now',
#  ' He is great Dr',
#  ' who takes the time to listen',
#  ' ensures you are comfortable',
#  ' ',
#  ' he was very encouraging ',
#  ' sympathetic when I miscarried early in my first pregnancy',
#  '',
#  ' "Dr',
#  ' Cohan is absolutely wonderful',
#  ' I starting going to this practice during my first pregnancy',
#  ' I originally went in order to see one of the other doctors who was recommended to me by a friend',
#  ' However',
#  " I wasn't happy with that doctor",
#  ' so I chose to see Dr',
#  ' Cohan next time',
#  ' After that',
#  ' I scheduled all of my appointments with him',
#  ' I even chose to have him do my c-section (baby was breech)',
#  ' He was willing to spend however much time with me that I needed in order to make sure that I was completely comfortable with everything that was going on during each stage of my pregnancy',
#  ' Since having my baby 8 months ago',
#  ' I have recommended 2 other expectant friends to him ',
#  ' they have both been very happy with their experiences as well',
#  '',
#  " 'He is wonderfully helpful ",
#  ' takes the time to really listen to all of your questions before he leaves the office',
#  ' A wonderful practice in general',
#  ' ',
#  ' Dr Cohan really knows his stuff',
#  ' He made me very comfortable with my pregnancy ',
#  ' has a great personality',
#  '',
#  " 'Absolutely amazing",
#  ' caring doctor',
#  ' Spent the time to make a treatment plan WITH me - not FOR me',
#  ' Always took the time to make sure I understood what was going on with my body',
#  ' Very personable',
#  ' Good in stressful situations',
#  '',
#  '["Dr',
#  ' Ramsey has been my physician for more than 10 years',
#  ' He takes care of all my gyne needs',
#  ' he delivered my babies ',
#  ' now is helping me navigate menopause',
#  ' But if I have a bad cold he is happy to see me for that too',
#  ' I never feel rushed when I need to discuss my issues with him',
#  ' His staff is friendly ',
#  ' efficient',
#  ' When I needed surgery',
#  ' they did my blood tests ',
#  ' EKG so I did not need to go someplace else for another appointment',
#  ' I have recommended him to many friends ',
#  ' co workers with confidence that he will take good care of them',
#  ' They took care of my insurance too',
#  ' I am planning to be in Dr',
#  " Ramsey's good care for many more years",
#  '',
#  " 'Not happy whatsoever with the service I received",
#  ' I will not be going back',
#  '',
#  '',
#  '',
#  '',
#  'ever',
#  '',
#  '',
#  '',
#  '',
#  '',
#  " 'I feel like I have hit the jackpot with Dr",
#  ' Ramsey',
#  ' He is an amazing',
#  ' knowledgeable',
#  ' caring ',
#  ' compassionate doctor',
#  ' His staff is kind ',
#  ' caring as well',
#  ' I am scheduled for surgery this weekend ',
#  ' I can not wait to have it done',
#  ' I am have been so impressed with the time he spends',
#  ' how thorough he is with his exam',
#  ' I disagree with the negative comments that other women have made',
#  ' He is so caring ',
#  ' compassionate',
#  ' He has found answers to things I have complained to other doctors about ',
#  ' had dismissed',
#  ' He has cures ',
#  ' answers to things I have dealt with for years',
#  ' He truly cares about the whole person',
#  ' I know that it is just a matter of time ',
#  ' I will be on the right path for these female issues which have interrupted ',
#  ' lowered my quality of life',
#  ' I could not be more thankful for finding him',
#  ' I called my PCP (who referred me to Dr',
#  'Ramsey) ',
#  ' told him he should be his #1 referral for woman looking for uro-gyne',
#  ' I thank God I have him as my doctor',
#  'I will recommend him',
#  '',
#  " 'I have been a patient ever since Dr",
#  " Ramsey took over a previous gynecologist\\'s practice some years ago",
#  ' He listens well',
#  '',
#  '',
#  'like "talking to a girlfriend',
#  ' He has performed two operations on me',
#  ' correcting two conditions',
#  ' Has repaired my bladder',
#  ' also my bartholin gl',
#  '',
#  '',
#  'both excellent outcomes',
#  ' ',
#  " surprisingly didn\\'t need prescribed painkillers afterwards",
#  ' Dr',
#  " Ramsey makes me feel as though I\\'m his only patient",
#  ' as he stays in room for some time to explain ',
#  ' discuss any condition',
#  ' Perhaps his taking time with patients is why some have had to wait longer than desired for their turns',
#  '',
#  " 'Quick to get an appointment - probably because no one wants to go there",
#  ' Staff mixes up payments',
#  ' Doctor prescribed a drug after warnening that I had allegry to this drug',
#  ' He does not seem to listen or care',
#  '',
#  " ''",
#  " 'Dr",
#  ' Ramsey is an excellent surgeon',
#  ' He repaired my bladder 5 years ago ',
#  ' I have never had a single problem since the surgery',
#  ' Some people I know that had the same type of surgery with other surgeons have not had such positive results',
#  ' I would not hesitate to reccomend him',
#  '',
#  ' "I think he\'s overly confident',
#  ' (wants to second-guess other specialists outside of the uro-gyn area) borderline arrogant',
#  ' (somewhat condescending) ',
#  ' chronically late',
#  ' Great staff though',
#  ' shiny new office',
#  ' expensive',
#  '',
#  "['Always have a positive experience",
#  ' Hardly have to wait at all',
#  ' Thorough coverage of health issues that matter to me',
#  '',
#  " 'Excellent doctor",
#  ' knowledgeable with great bedside manner',
#  ' Would highly recommend for the best care for your unborn child',
#  '',
#  " 'no comment didnt have a good child birth experince was never the same afterwards physically",
#  '',
#  ' "Neither he nor his staff told me the procedure I was having would be irreversible should I want to have more kids',
#  ' He just did what he wanted to do',
#  " He's a jerk ",
#  ' a poor doctor',
#  '',
#  " 'I went to Dr",
#  ' Hanna because of the wonderful reviews on several sites',
#  ' If the level of care I received is considered "Excellent" in Decatur then I pity you poor women',
#  ' As a military wife I have seen my fair share of OB/GYNs',
#  ' 8 to be exact',
#  ' This was the most horrible experience I have ever had',
#  ' He was rough',
#  ' ',
#  " didn\\'t keep a female nurse in the room with him when he performed the procedure",
#  ' Every male I have been to (6 of the 8) has always kept a female present',
#  ' He totally blew off one of my main',
#  ' very real complaints ',
#  ' tried to pass it off as caused by something obviously not related despite my telling him several times I had none of the symptoms',
#  ' It was very awkward ',
#  ' uncomfortable',
#  ' ',
#  " I couldn\\'t wait to get out of there",
#  ' The staff were decent',
#  ' although his nurse would ask me a question ',
#  ' interrupt me before I could finish',
#  ' Very unprofessional',
#  ' ',
#  ' very difficult to underst',
#  ' when he speaks',
#  '',
#  " 'He is such a wonderful doctor",
#  ' Anyone would be lucky to have him as a doc',
#  '',
#  '',
#  '',
#  " 'Incredible doctor -- highly recommend him",
#  ' Straight-forward',
#  ' honest',
#  ' helpful',
#  ' humble',
#  ' skilled',
#  ' confident',
#  ' wonderful',
#  '',
#  "['I will not be returning to this office after having my first baby with this office",
#  ' I had many issues with the hospital stay during the baby’s birth',
#  ' including not getting pain meds for over 10 hrs post-partum',
#  ' due to Dr',
#  ' ',
#  ' staff error',
#  ' Dr',
#  ' Spellman is condisensing ',
#  ' brash',
#  ' Huge turnover off the office staff',
#  '',
#  '',
#  'now I underst',
#  ' why',
#  '',
#  " 'Terrible bedside manner",
#  'Was very rough during pap smear ',
#  ' I bled for a day after',
#  'She explained there may be spotting ',
#  ' at 51yrs of age',
#  'I have never spotted after a exam',
#  '',
#  ' "I have to say I have not had a good experience with OB- Gyne Associates of of Libertyville',
#  ' I am pregnant with my first child ',
#  " I feel like a new patient every time I'm in the office even though I have been going back once a week",
#  ' Nobody seems to remember me',
#  ' Its like impossible to get an appointment at the place even though have 4 doctors on staff',
#  ' Not once has any of the doctors ever let me know the progress of pregnancy unless I asked',
#  ' The doctors are always in a hurry ',
#  ' have no interest in getting to know you',
#  ' For a first time mom who has no idea what is going on they should be a little more informative',
#  ' I have never waited less than 30 mins to be see by a doctor on average an appointment takes about an hour',
#  ' When you call in to the office with a question or concern you can never talk to someone right away you are always put on hold',
#  ' OR even told the will call you back',
#  ' they never call back',
#  ' I will not be going back to this place once I complete my care for this pregnancy',
#  '',
#  ' "Dr Spellman is not my usual Dr at this practice',
#  ' ',
#  ' I did end up seeing her for a problem I was having',
#  ' She was great- extremely knowledgeable ',
#  ' seemed very interested in getting to the root of my problem',
#  ' I had read some negative things online ',
#  " didn't know what to expect",
#  ' so I was pleasantly surprised to experience the opposite at my visit',
#  '',
#  " '-- The st",
#  'ard phone greeting at this practice is "OB-Gyne Associates',
#  ' please hold',
#  '',
#  '',
#  ' with a wait time between 5-30 minutes',
#  ' -- Follow-up calls for lab results are non existent',
#  " I\\'ve had to call them each ",
#  ' every time after patiently waiting for their call that never came',
#  ' -- In office delays are a given',
#  " Over the last 15+years that I\\'ve been going to this practice I\\'ve probably been seen on time just a h",
#  'ful of times',
#  " Not to mention how many times I\\'ve arrived early",
#  ' or worse yet',
#  ' been half dressed in the exam room waiting on the doctor only to find out that the doctor has been called away for an "emergency" delivery',
#  ' -- These doctors also frequently push services/procedures on you without really covering all options',
#  ' -- The proof is in the pudding',
#  ' Check out a quick internet search on yelp',
#  ' health grades',
#  " etc I\\'ve stuck with this practice too long ",
#  " I wish I\\'d have left a lot sooner",
#  '',
#  " 'I went to Dr Spellman years ago due to two reasons: terribly painful periods",
#  ' period spaced 2-3-4 months apart',
#  ' I was only 18-19 at the time',
#  ' She did a needle biopsy on breast cyst (came back normal)',
#  ' looking back not sure that was a necessary procedure',
#  ' She wanted to put me on rheumatoid arthritis meds (I refused) to help my menstrual cramp pain (which was severe)',
#  ' Years later I begged another doctor to test my thyroid levels (family history)',
#  ' I was dx with autoimmune thyroid issue (TSH 37 -- normal is 1-2)',
#  ' Going on meds',
#  ' my periods became normal (28 days) ',
#  ' pain lessened greatly',
#  ' If Dr Spellman had just tested my thryoid levels (simple blood test) I could have avoided years of pain',
#  '',
#  ' "Wow',
#  " I'm shocked at these comments",
#  " I've been a patient at this practice for over 9 years ",
#  ' love',
#  ' love',
#  ' love all the docs',
#  ' The staff is ever changing',
#  ' however',
#  ' the care has always been great',
#  ' I do agree',
#  ' sometimes the wait can be long-',
#  ' then again',
#  " I know I'll be getting the same attention when the doctor sees me",
#  " I've recommended this practice to many friends ",
#  ' family members',
#  ' ',
#  ' they are all very happy with this group :)"',
#  " 'I thought she was very knowledgeable ",
#  ' took me seriously ',
#  ' listened',
#  ' She made me feel comfortable despite this always being an unpleasant exam',
#  ' The only fault I see is with the wait time',
#  ' ',
#  ' she addressed all of my concerns ',
#  ' I did not feel rushed',
#  '',
#  " 'Horrible bedside manners",
#  ' Do not recommend this Dr',
#  ' to anyone',
#  ' I love my new Dr',
#  'Chan',
#  ' Spellman should learn some bedside manners from her',
#  '',
#  ' "I stopped going to this office after a few years because I found some of the nurses to be very unfriendly ',
#  ' condescending',
#  ' I had developed a couple of problems that required surgery',
#  ' ',
#  ' whenever I called to speak to the doctor (twice)',
#  ' (Spellman) I was always directed to the robotic gate-keeper that one must speak to before one can speak to a doctor',
#  ' I had two abnormal tests ',
#  ' was not notified about them until two weeks after',
#  ' Dr',
#  ' Spellman is aloof ',
#  ' blocks her number on the rare occasion that she does call',
#  'She is an intelligent doctor',
#  ' ',
#  " doesn't seem really interested in her job",
#  ' I have found another practice',
#  '',
#  " 'I have never cried after leaving an appointment before",
#  ' Dr',
#  ' S strong-armed me into an Rx I was not comfortable with',
#  ' She was condescending ',
#  ' rolled her eyes when I expressed my concerns',
#  ' She did not explain why she would not perscribe the same Rx that another doctor in her office had given me',
#  ' I felt very disrespected ',
#  ' hurt ',
#  ' will never go back',
#  ' Ladies',
#  ' please keep looking for someone else',
#  ' You deserve respect',
#  '',
#  " 'She misdiagnosed me",
#  ' which shows terrible lack of knowledge',
#  '',
#  ' My dermatologist said "Oh',
#  ' don\\\'t worry about it it\\\'ll go away" (which it did)',
#  '',
#  '',
#  '',
#  ' Spellman was ridiculous prescribing me medication ',
#  " diagnosing me with something I didn\\'t have",
#  '',
#  'terrible bedside manners',
#  ' Go here for Nakanishi ',
#  ' not Spellman',
#  '',
#  " 'did not care for dr",
#  ' spellman',
#  ' she was very short with me',
#  ' terrible bedside manner',
#  ' the nurse shoved papers in my h',
#  ' when i got home ',
#  ' read them it was for a mammorgram order',
#  ' that the docter did not even tell me i needed or even discussed it with me not only is she rude ',
#  ' unprofessional the office staff are very rude',
#  ' they keep charging me a higher co pay on my insurance than they are suppose to i guess they don;t know how to read either',
#  '',
#  " 'I don\\'t mind the other doctors in this practice",
#  ' in fact I love Nakanishi',
#  ' ',
#  ' Spellman was awful',
#  ' During my pregnancy she wrote in my chart to "stop eating desserts" b/c she thought I was gaining weight too quickly',
#  ' even though I worked out 4-5 days a week ',
#  " wasn\\'t even eating desserts",
#  ' She never even asked what I was doing about the weight gain',
#  ' ',
#  ' I ended up gaining 30lbs',
#  '',
#  '',
#  'which I was told was perfectly healthy for me to do',
#  ' She also did a post-partum check for me since the delivering doctor had an emergency',
#  '',
#  '',
#  'I was there for a 2 week checkup ',
#  ' she thought I was there for a 6 week check up',
#  ' Did she not even bother to read my chart',
#  '',
#  '',
#  " 'I had a very pleasant pregnancy with Dr",
#  ' Spellman',
#  ' For every pregnancy visit I had a ton of questions ',
#  ' she patiently answered all of them',
#  ' I had some minor complications during the last trimester ',
#  ' was very glad that Dr',
#  ' Spellman h',
#  'led the situation realistically',
#  ' /she did not over disgonse ',
#  ' put me on medication unnecssarily',
#  ' She delivered my baby at Condell Medical ',
#  ' did a very good job',
#  ' I liked all the doctors in her practise group too',
#  '',
#  ' "I think they pushed servces I didn\'t need so they could charge me more',
#  ' I came just for a pap smear ',
#  ' was billed for much more than just a pap smear',
#  " I didn't feel comfortable with her",
#  " Now I'm pregnant ",
#  " I'm not going there for prenatal care/delivery",
#  " I don't recommend",
#  ' Terrible bedside manner',
#  '',
#  ' "I saw Dr',
#  ' Spellman once during my pregnancy',
#  ' The visit we had was about the AFP/MMS testing which I was opposed to',
#  ' When I declined the testing she became very agitated ',
#  ' upset with me',
#  ' asking me',
#  " don't you want to know",
#  '',
#  ' When I told her I saw no reason for doing the testing as it would not change our minds either way',
#  '',
#  '',
#  ' she was exasperated',
#  " Pushing testing that someone doesn't want would seem to me to be for insurance money",
#  ' I had two healthy children before that pregnancy (he was healthy',
#  ' too) ',
#  ' no risks',
#  ' I felt her reaction was over the top ',
#  ' she was darn pushy',
#  ' We did not see her again throughout the rest of the pregnancy ',
#  ' thank goodness she was not the doctor on call when I was delivering',
#  '',
#  " 'She does not have a good bedside manner",
#  ' she wasnt my main pysician ',
#  ' did a few of my pregnancy appointments',
#  ' I did not feel comfortable',
#  '',
#  " 'She has 0 personality ",
#  ' barely spoke when we came in for our monthly ',
#  ' weekly pregnancy visits',
#  ' Nothing warm',
#  ' nothing nurturing about her - something you expect in the doc who could potentially deliver you baby',
#  ' Unfortunately she was on call when we went into labor',
#  ' She showed up late',
#  ' casually came in the room',
#  ' misread our progress',
#  ' ',
#  ' abruptly left the room to leave us with the nurse to push',
#  ' The nurse had to leave us as the baby was crowning to go find Dr',
#  ' Spellman',
#  ' Our baby began to come out with no medical personnel in the room',
#  ' Truly sad',
#  '',
#  " 'It is my opinion that Dr",
#  ' Spellman has terrible bed-side manner',
#  ' She did not respect my wishes when she delivered my baby',
#  ' ',
#  ' I feel that her actions may have contri',
#  'ed to the complications that I suffered',
#  ' I would strongly recommend against using this physician',
#  '',
#  '["I\'ve been a patient of Dr Ray\'s for 5 years ',
#  ' like that she explains all options',
#  " doesn't judge my choices",
#  ' ',
#  ' is very friendly',
#  ' I have PCOS ',
#  ' am now pregnant ',
#  ' feel good about being under her care',
#  ' I have also referred 3 friends to her ',
#  " they are all equally pleased with the care they've received",
#  '',
#  " 'This place is awful",
#  ' ALWAYS at least a half hour behind',
#  ' I went there for an exteranl yeast infection',
#  ' When I went back for my follow-up Dr',
#  " Ray didn\\'t even read the file which contained HER diagnosis ",
#  ' made me have an internal exam to check out the situation',
#  ' Also',
#  ' the NP told me I had herpes when she was examining me',
#  ' I said are you sure',
#  ' ',
#  ' she looked up ',
#  ' smiled ',
#  ' said',
#  ' "Yep',
#  ' Sure looks like it',
#  " I don\\'t have herpes--it was a cut from shaving",
#  ' When I brought up the poor bedside manner to Dr',
#  " Ray she didn\\'t even act like she cared",
#  " I switch dr\\'s ",
#  ' office ',
#  " I\\'ve never been more pleased",
#  '',
#  " 'Dr",
#  ' Ray',
#  ' is one of the best ',
#  ' most attentive doctors I have encountered',
#  ' We had fertility issues ',
#  ' she was extremely knowledgeable ',
#  ' patient',
#  '',
#  ' "Office staff is incredibly unhelpful ',
#  ' unresponsive',
#  ' Doctor Ray also fails to follow up',
#  " Overall worst medical experience I've ever had",
#  " Please do not go to this doctor's office",
#  " It's called Nye Partners in Women's Health in Chicago",
#  '',
#  "['I absolutely adore Dr Nakanishi",
#  ' She is so kind ',
#  ' caring',
#  ' She makes you feel comfortable at all times',
#  ' She recently explained to me in detail with diagrams something of concern she felt in my exam',
#  ' She genuinely cares ',
#  ' takes the time needed',
#  " She is wonderful'",
#  " 'My complaint is that DURING my annual exam (while the instrument was actually inside me",
#  ' she left the room to take a phone call',
#  ' This was',
#  ' to say the least',
#  ' rude ',
#  ' unprofessional',
#  ' No one should be more important than the patient during that very private',
#  ' vulnerable moment',
#  ' It was an insensitive act that made me feel not valued',
#  '',
#  ' "Dr',
#  " Nakanishi is the best doctor I've ever seen",
#  ' very genuine',
#  ' knowledgeable & sweet',
#  ' Highly recommend',
#  '',
#  " 'She s the best i have ever seen",
#  '',
#  'She was so caring ',
#  'so helpful',
#  'she s the best doctor',
#  '',
#  '',
#  ' "The best OBGYN I\'ve had',
#  ' Great bedside manner',
#  ' ',
#  ' she is very knowledgeable',
#  ' She seems to genuinely care about whatever concerns you bring to her',
#  '',
#  " 'She is the best OBGYN I have EVER Had",
#  ' She is gentle',
#  ' sweet ',
#  ' most of all down to earth',
#  ' She is very soft spoken while concerned for each ',
#  ' every patient',
#  ' She makes sure that you are well before she departs',
#  ' She has awesome bedside manners',
#  ' She is young',
#  ' ',
#  ' very sweet',
#  ' Would recommened her to anyone who has had horrible OBGYN experiences in the past',
#  ' I had a horrible doctor with my first child',
#  ' ',
#  ' was terrified to have another C-Section',
#  ' But once I meet her',
#  ' my fears were gone',
#  ' She was incredible',
#  ' She is very concerned for her patients in a sincere way',
#  ' She talked to me throughout the entire surgery to make sure I was OK',
#  ' Would highly recommend',
#  '',
#  '["Dr',
#  ' Johnson takes time ',
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3628
#    3629             # turn me into an ndarray
# -> 3630             value = sanitize_index(value, self.index, copy=False)
#    3631             if not isinstance(value, (np.ndarray, Index)):
#    3632                 if isinstance(value, list) and len(value) > 0:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in sanitize_index(data, index, copy)
#     517
#     518     if len(data) != len(index):
# --> 519         raise ValueError('Length of values does not match length of index')
#     520
#     521     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %%
#hgrd.to_excel(r'C:\Users\rramn\Documents\Healthcare_analytics\physician_reviews_mining\Reviews\healthgrades_reviews_sentences.xlsx',header=True)
ratemd.to_excel(r'/Users/sujaikarunakaran/Desktop/Assignments/Spring 2020/Ranga/Final Project/Ratemds - Illinois/New/complete_data_sentences_withbut.xlsx',header=False)

# %%
#pip install vaderSentiment
#from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
#analyser1 = SentimentIntensityAnalyzer()
#def sentiment_analyzer_scores(sentence):
#    score = analyser1.polarity_scores(sentence)
    #print("{:-<40} {}".format(sentence, str(score)))
#    print(score)
#    if score['compound']>0.05:
#        return "Positive"   
#    elif score['compound']<-0.05:       
#        return "Negative"    
#    else:       
#        return "Neutral"

# %%
txt = "he not only loves to bring new life into the world but dr. drachler is seriously concerned about the quality of our lives"
sentiment_analyzer_scores(txt)
# Out:
# {'neg': 0.162, 'neu': 0.838, 'pos': 0.0, 'compound': -0.4676}
# 'Negative'

# %%
from textblob import TextBlob

# %%
#Function to determine the sentiment of the sentence
i=[]
j=[]
k=[]
def sentiment_analyser(text):
    analysis = TextBlob(text)
    if analysis.sentiment[0]>0:
        i.append(1)
        #return "Positive"   
        return analysis.sentiment[0]
    elif analysis.sentiment[0]<0:       
        j.append(1)
        #return "Negative"    
        return analysis.sentiment[0]
    else:       
        k.append(1)
        #return "Neutral"
        return analysis.sentiment[0]

# %%
nr1,nc1=df.shape

# %%
#function to take all the sentences, identify sentiment and provide a dictionary with key as sentence and value as
#sentiment
def sentence_sentiment(df):
    main_list = []
    nr1,nc1 = df.shape
    for j in range(nr1):
        t1=ratemd.iloc[j,2]
        sub_list = []
        for x in range(len(t1)):
            d = {}
            senti = sentiment_analyser(t1[x])
            d[t1[x]] = senti
            for f in d.copy():
                if d[f] == 'Neutral':
                    d.pop(f)
            sub_list.append(d)
        main_list.append(sub_list)
    return main_list

# %%
def sentence_sentiment1(df):
    main_list = []
    nr1,nc1 = df.shape
    for j in range(nr1):
        t1=df.iloc[j,7]
        senti = sentiment_analyser(t1)
        main_list.append(senti)
    return main_list

# %%
sentiment = sentence_sentiment1(ratemd)

# %%
len(sentiment)
# Out:
# 840

# %%
type(sentiment[0][0])
# Out:
# dict

# %%
for x in range(len(sentiment)): 
    q = sentiment[x]
    for a in range(len(q)):
        sent = q[a]
        for f in sent.keys():
            if sent[f] == 'Neutral':
                del(sent[f])

# %%
for x in range(len(sentiment)): 
    q = sentiment[x]
    for a in range(len(q)):
        sent = q[a]
        for f in sent.copy():
            if not sent[f]:
                sent.pop(f)

# %%
filter(None, sentiment)

# %%
len(sentiment)
print(len(i))
print(len(j))
print(len(k))
# Out:
# 832
# 254
# 270

# %%
sentiment
# Out:
# ['Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#
# 36                                            competent   Positive
# 38                               I trust him completely   Positive
# 41           Drachler to refer me to my other physicians  Negative
# 43                                      Drachler greatly  Positive
# 44      He not only loves to bring new life into the ...  Positive
# 46      Drachler is seriously concerned about the qua...  Negative
# 52                                        to be healthy   Positive
# 59      send me away (like the previous OB/GYN which ...  Negative
# 61                       Drachler is truly one of a kind  Positive
# 65                       she was pregnant within 30 days  Positive
# 68                               Drachler is very caring  Positive
# 74            will not end the visit until you are ready  Positive
# 77      Drachler is one of the best doctors I have ev...  Positive
# 78                        He is extremely knowledgeable   Negative
# 83      As you know most doctors see you for 5-10 min...  Positive
# 87                   Drachler spent with us 1 whole hour  Positive
# 90                  I was very impressed with no rushing  Positive
# 93                      especially his positive attitude  Positive
# 97                               He is the absolute best  Positive
# 101                                                 more  Positive
# ...                                                  ...       ...
# 80543   I forgot to mention that she also did the sam...  Positive
# 80546                         Both high risk pregnancies  Positive
# 80547                              She is a wonderful dr  Positive
# 80554            When I questioned her she became angry   Negative
# 80556                      I consulted with two other dr  Negative
# 80561             Glad I was strong to listen to myself   Positive
# 80562        happy not to have the un-necessary surgery   Positive
# 80563                                have a wonderful dr  Positive
# 80569   the doctor will count for a lot of unnecessar...  Negative
# 80575  she is sending all blod tests to alexian broth...  Negative
# 80578    I felt this visit was a complete waste of time   Negative
# 80580            Overall I would rate this visit : AWFUL  Negative
# 80582                                                :("  Negative
# 80583                 'She delivered my first two babies  Positive
# 80584                               She\'s a good doctor  Positive
# 80586                           she gets very exciteable  Positive
# 80587             which is not good for patients like me  Negative
# 80592                            Scared me half to death  Negative
# 80595            I found a much calmer doctor after that  Positive
# 80598   she is sending all blod tests to alexian brot...  Negative
# 80600                                      "Fantastic Dr  Positive
# 80602                         both high risk pregnancies  Positive
# 80603                     I wouldn't want any other Dr h  Negative
# 80605                                Very knowledgeable"  Positive
# 80606   'During my visit I felt that I was treated ve...  Positive
# 80607  I would absolutely recommend this doctor to my...  Positive
# 80609           I felt this visit was an amazing success  Positive
# 80613   'During my visit I felt that I was treated po...  Negative
# 80616    I felt this visit was a complete waste of time   Negative
# 80618            Overall I would rate this visit : AWFUL  Negative
#
# [29133 rows x 3 columns]

# %%
sent = []
for x in range(len(df["Sentiment"])):
    if df["Sentiment"][x] > 0:
        sent.append("Positive")
    elif df["Sentiment"][x] < 0:
        sent.append("Negative")
    else:
        sent.append("Neutral")

# %%
len(sent)
# Out:
# 6621

# %%
df["sent"] = sent

# %%
df_negative.to_csv(r'/Users/sujaikarunakaran/Desktop/Assignments/Spring 2020/Ranga/Final Project/Final/RateMds/Phrases_Negative.csv', header=True, index=False)

# %%
df_positive.to_csv(r'/Users/sujaikarunakaran/Desktop/Assignments/Spring 2020/Ranga/Final Project/Final/RateMds/Phrases_Positive.csv', header=True, index=False)

# %%
ratemd.to_csv(r'/Users/sujaikarunakaran/Desktop/Assignments/Spring 2020/Ranga/Final Project/Final/Healthgrades/All_Healthgrades_v3 copy1.csv', header=True, index=False)
