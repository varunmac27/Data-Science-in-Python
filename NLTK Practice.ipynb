# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/jigyasasachdeva/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.corpus import wordnet

# %%
import pandas as pd

df = pd.read_excel (r'/Users/jigyasasachdeva/Desktop/SideEffects.xlsx', columns=['text'])
print (df)
# Out:
#           hurts       hurts   \
# 0          pain        pain
# 1          ache        ache
# 2          feel        feel
# 3        chills      chills
# 4         fever       fever
# ..          ...          ...
# 251    spinning    spinning
# 252     passing     passing
# 253  scratching  scratching
# 254    sweating    sweating
# 255    disorder    disorder
#
# ...

# %%
import nltk
from nltk.stem import PorterStemmer
porter_stemmer = PorterStemmer()
word_data = " "

# %%
#Final code

nltk_tokens = nltk.word_tokenize(word_data)
wordnet_lemmatizer = WordNetLemmatizer()
#Next find the roots of the word
for w in nltk_tokens:
       print (wordnet_lemmatizer.lemmatize(w))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-76958e7384d5> in <module>
#       2
#       3 nltk_tokens = nltk.word_tokenize(word_data)
# ----> 4 wordnet_lemmatizer = WordNetLemmatizer()
#       5 #Next find the roots of the word
#       6 for w in nltk_tokens:
#
# NameError: name 'WordNetLemmatizer' is not defined

# %%
import nltk

w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
lemmatizer = nltk.stem.WordNetLemmatizer()

def lemmatize_text(text):
    return [lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text)]

# %%
df['text_lemmatized'] = df.text.apply(lemmatize_text)

# %%
def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)
from nltk.stem import WordNetLemmatizer 
lemmatizer = WordNetLemmatizer()
print([lemmatizer.lemmatize(w, get_wordnet_pos(w)) for w in nltk.word_tokenize(word_data)])

# %%
def process_genre(word_data):
    for genre in word_data.split(" "):
        result = []
        for syn in wordnet.synsets(genre):
            for l in syn.lemmas():
                result.append(l.name())
        print(result)
process_genre(word_data)
# Out:
# ['angina', 'angina_pectoris', 'angina']
# ['cardiac']
# []
# ['increase', 'increase', 'increased']
# ['myocardial']
# ['palpitation', 'shaking', 'shakiness', 'trembling', 'quiver', 'quivering', 'vibration', 'palpitation']
# ['tachycardia']
# ['anxiety', 'anxiousness', 'anxiety']
# ['emotional', 'emotional', 'emotional', 'aroused', 'emotional', 'excited', 'worked_up']
# []
# ['concern', 'worry', 'headache', 'vexation', 'headache', 'head_ache', 'cephalalgia']
# ['heat', 'heat_energy', 'hotness', 'heat', 'high_temperature', 'heat', 'warmth', 'heat', 'warmth', 'passion', 'estrus', 'oestrus', 'heat', 'rut', 'heat', 'heating_system', 'heating_plant', 'heating', 'heat', 'heat', 'heat_up', 'heat', 'inflame', 'stir_up', 'wake', 'ignite', 'heat', 'fire_up', 'heat', 'hot_up', 'heat_up']
# ['hyperactivity']
# ['insomnia']
# ...

# %%
import nltk
from nltk.stem import PorterStemmer
porter_stemmer = PorterStemmer()
levothryoxine_se = "systolic tachycardia palpitations increased myocardial raynaud cardiomyopathy cerebrovascular peripheral insomnia headache emotional anxiety agitation dizziness irritability fatigue drowsiness speech twitching depression jitteriness agressive dysphoria euphoria exacerbation formication outbursts overstimulation parathesia psychosis restlessness talkitiveness seizure decreased xerostomia abdominal nausea vomitting diarrhea constipation dyspepsia teeth tooth anorexia bruxism unpleasant diaphoresis skin alopecia dermatillomania urticaria stevens-johnson toxic weight dysmenorrhea urinary impotence erectile frequent prolonged anaphylaxis angioedema hypersensitivity infection dyskinesia rhabdomyolysis tremor blurred myadriasis dyspnea fever accidental hypertension blood infarction phenomenon accident vascular lability Tourette syndrome distrubances behavior appetite pain clenching taste photosensitivity rash epidermal loss libido tract dysfunction erections reaction vision injury pressure disease vocal tics anger Gilles necrolysis "

# %%
def process_genre(levothryoxine_se):
    for genre in levothryoxine_se.split(" "):
        result = []
        for syn in wordnet.synsets(genre):
            for l in syn.lemmas():
                result.append(l.name())
        print(result)
process_genre(levothryoxine_se)
# Out:
# ['systolic']
# ['tachycardia']
# ['palpitation', 'shaking', 'shakiness', 'trembling', 'quiver', 'quivering', 'vibration', 'palpitation']
# ['increase', 'increase', 'increased']
# ['myocardial']
# []
# ['cardiomyopathy', 'myocardiopathy']
# ['cerebrovascular']
# ['peripheral', 'computer_peripheral', 'peripheral_device', 'peripheral', 'peripheral']
# ['insomnia']
# ['concern', 'worry', 'headache', 'vexation', 'headache', 'head_ache', 'cephalalgia']
# ['emotional', 'emotional', 'emotional', 'aroused', 'emotional', 'excited', 'worked_up']
# ['anxiety', 'anxiousness', 'anxiety']
# ['agitation', 'agitation', 'ferment', 'fermentation', 'tempestuousness', 'unrest', 'agitation', 'agitation', 'excitement', 'turmoil', 'upheaval', 'hullabaloo', 'agitation']
# ['dizziness', 'giddiness', 'lightheadedness', 'vertigo']
# ...

# %%
import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet
syn = wordnet.synsets('febrile')
syn
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/jigyasasachdeva/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [Synset('febrile.a.01')]

# %%
str = "5-alpha reductase, abdominal muscles, abdominoplasty, abduction, ablation, abrasion, abscess, abutment, acceptance-based therapies, accommodation, ACE inhibitor, acetabulum, acetaldehyde, acetaminophen, acetylcholine, Achilles' tendon, achlorhydria, acne, acquired immunodeficiency syndrome, acquisition, acromioclavicular joint, actin, actinic keratosis, active surveillance, acupressure, acupuncture, acute, acute pain, acute urinary retention, adaptability, adaptive immunity, addiction, adduction, adenocarcinoma, adenoma, adenosine triphosphate, adequate intake, adhesion, adipose tissue, adjuvant therapy, adrenal glands, adrenaline, adult day services, adulterant, advance care directive (or advance medical directive), advanced sleep phase syndrome, aerobic, aerobic exercise, aerophagia, aesthetician, after-cataract, age-related cognitive decline, age-related macular degeneration, agnosia, agonist, agoraphobia, AIDS, AIDS dementia, albinism, albumin, albuminuria, alcohol abuse, alcohol dehydrogenase, alcohol dependence, alcoholism, aldosterone, alendronate, alimentary canal, allele, allergen, allergic, allergic rhinitis, allergy, allodynia, alopecia areata, alopecia totalis, alopecia universalis, alpha blockers, alpha cells, alpha hydroxy acids, alpha waves, alpha-delta sleep, alpha-glucosidase inhibitor, alveolar bone, alveoli, Alzheimer's disease, ambulatory, AMD, amnesia, amputation, Amsler grid, amygdala, amylase, amyloid, anaerobic, anaerobic exercise, anagen, anal canal, analgesia, analgesic, analytic variability, anaphylaxis, androgen, androgenetic alopecia, androgen-independent prostate cancer, anemia, anencephaly, anesthesia, aneurysm, angina pectoris, angiogenesis, angiography, angioplasty, angiotensin, angiotensin I, angiotensin II, angiotensin II
needle ablation, transurethral resection of the prostate, transverse processes, traumatic grief, tremor, tricuspid valve, tricyclic antidepressant, trigeminal neuralgia, trigger, trigger point, triglyceride, triiodothyronine, triptans, trochlea, troponins, trust, trypsin, TSH, tumor, tunica albuginea, tympanic membrane, tympanometry, type 1 diabetes, type 1 osteoporosis, type 2 diabetes, type 2 osteoporosis, ulcer, ultrasound, unopposed estrogen, unresolved losses, unsaturated fat, unstable angina, upper airway resistance syndrome, upper esophageal sphincter, urea, ureter, urethra, urethral hypermobility, urethritis, urgency, urinary frequency, urinary incontinence, urinary tract, urologist, urticaria, uveitis, uvula, uvulopalatopharyngoplasty, vaccination, vacuum erection devices, vaginismus, valves, variant angina pectoris, vascular, vascular dementia, vascular surgery, vasculitis, vasectomy, vasoconstrictor, vasodilation, vasodilator, vasospasm, vector, vein, venous, venous leak, ventilator, ventricle, ventricular arrhythmia, ventricular fibrillation, ventricular myocardium, ventricular rupture, ventricular septal defect, ventricular tachycardia, venules, vertebra, vertebral artery, vertebroplasty, vertigo, very low-calorie diet, very-low-density lipoprotein, vestibular system, viral, virtues, virulent, viscera, visceral fat, visual acuity, visual cortex, visual field, visualized laser-assisted prostatectomy, vital signs, vitamin D, vitrectomy, vitreous humor, VLDL, VO2 max, volatile oils, VSD, vulnerary, vulvar vestibulitis, vulvodynia, wall stress, warfarin, wart, water brash, Weber test, Wernicke-Korsakoff syndrome, Wernicke's area, whiplash, white matter, white-coat hypertension, withdrawal, working memory, xanthelasma, xanthoma, YAG capsulotomy, yohimbine, zonules, zoonotic disease"

def process_genre(str):
    for genre in str.split(", "):
        result = []
        for syn in wordnet.synsets(genre):
            for l in syn.lemmas():
                result.append(l.name())
        print(result)
process_genre(str)
# Out:
# []
# []
# ['abdominoplasty', 'tummy_tuck']
# ['abduction', 'abduction']
# ['ablation', 'extirpation', 'cutting_out', 'excision', 'ablation']
# ['abrasion', 'scratch', 'scrape', 'excoriation', 'abrasion', 'attrition', 'corrasion', 'detrition', 'grinding', 'abrasion', 'attrition', 'detrition']
# ['abscess']
# ['abutment', 'abutment']
# []
# ['adjustment', 'accommodation', 'fitting', 'accommodation', 'accommodation', 'accommodation', 'accommodation', 'accommodation']
# []
# ['acetabulum', 'cotyloid_cavity']
# ['acetaldehyde', 'ethanal']
# ['acetaminophen', 'Datril', 'Tylenol', 'Panadol', 'Phenaphen', 'Tempra', 'Anacin_III']
# ['acetylcholine']
# []
# ['achlorhydria']
# ['acne']
# []
# ['acquisition', 'acquisition', 'learning', 'acquisition', 'skill', 'accomplishment', 'acquirement', 'acquisition', 'attainment']
# []
# ['actin']
# []
# []
# ['acupressure', 'G-Jo', 'shiatsu']
# ['acupuncture', 'stylostixis']
# ...

# %%
str = "vertigo"
def process_genre(str):
    for genre in str.split(", "):
        result = []
        for syn in wordnet.synsets(genre):
            for l in syn.lemmas():
                result.append(l.name())
        print(result)
process_genre(str)
# Out:
# ['dizziness', 'giddiness', 'lightheadedness', 'vertigo']
